# %% [markdown]
# # Cheatsheet From L19

# %% [markdown]
# ## Needed imports
#
# - import pandas as pd
# - import numpy as np
# - import seaborn as sns
# - import matplotlib.pyplot as plt

# %% [markdown]
# ### Useful functions for EDA

# %% [markdown]
# ### Data cleaning
#
# - To load data the syntax
#         Data = pd.read_csv('url' or 'file path')
#
# - Change formatting
#         pd.set_option('display.precision', 2)
#
#         syntax -> ('attribute for decimal precision', decimals needed)
# - Rename columns
#         data.columns = ["name","survived","sex","age","class"]
# - Dict-like replace
#         data = data.replace({'survived': {'yes': 1, 'no': 0}})
#
#         syntax -> ('column title': ('Value1': replacementValue, 'Value2':replacementValue))
# - Drop all rows which contain any missing data
#         titanic = titanic.dropna(axis=0)
#
#         syntax-> dropna: drop NA values;   Axis = 0 indicates rows

# %% [markdown]
# ### Basic Analysis
#
# - distribution based on a column
#         distributionHistogram = data.column.hist(bins=8, figsize=(7,5), grid=False)
#
# - distribution statistics for a column
#         distributionStatistics = data.age.describe()
#
# - grouped operations
#         groupedData = data.groupby(['Col1','Col2','Col3']).size().unstack()

# %% [markdown]
# ### Basic Visualizations (Seaborn & Matplotlib)
#
# - countplot using seaborn
#         sns.countplot(data=Data, x="class", hue="survived").set(title='Fig 2. Survival count by Class')
#
#         refer: https://seaborn.pydata.org/generated/seaborn.countplot.html#seaborn.countplot
#
# - barplot using matplotlib.pyplot
#         IMP: WE ARE USING GROUPED DATA HERE!
#         data_barplot = groupedData.plot.bar(stacked=True, color = ["lightblue", "lightpink"]
#
#
#         For syntax, refer: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
#         For simple, multiple and stacked barplot: https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm

# %% [markdown]
# # Seaborn Basics
#
# ###### credit: https://elitedatascience.com/python-seaborn-tutorial#step-2

# %% [markdown]
# ## Importing Libraries

# %%
# Pandas for managing datasets
import pandas as pd

# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline

# Seaborn for plotting and styling
import seaborn as sns

# %%
# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')


# Display first 5 observations
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %% [markdown]
# ## Seaborn Plotting Functions

# %%
# Recommended way
sns.lmplot(x='Attack', y='Defense', data=df)

# %%
# Scatterplot arguments
sns.lmplot(x='Attack', y='Defense', data=df,
           fit_reg=False, # No regression line
           hue='Stage')   # Color by evolution stage

# fit_reg=False to remove the regression line, since we only want a scatter plot.
# hue='Stage' to color our points by the Pokémon’s evolution stage.

# %% [markdown]
# ## Customize with MatPlotLib

# %%
# Plot using Seaborn
sns.lmplot(x='Attack', y='Defense', data=df,
           fit_reg=False, 
           hue='Stage')
 
# Tweak using Matplotlib
plt.ylim(0, 200)
plt.xlim(0, 160)
## ^^ exapands the axes limit
# Out:
# (0.0, 160.0)

# %% [markdown]
# ## Role of Pandas

# %%
# Boxplot
plt.figure(figsize=(9,6)) # Set plot dimensions
sns.boxplot(data=df)

# In turns out that this isn’t easy to do within Seaborn alone.
# Instead, it’s much simpler to pre-format your DataFrame.
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Color Palettes

# %%
# Fortunately, Seaborn allows us to set custom color palettes. 
# We can simply create an ordered Python list of color hex values.

pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# Violin plot with Pokemon color palette
plt.figure(figsize=(11,6)) # Set plot dimensions
sns.violinplot(x='Type 1', y='Attack', data=df, 
               palette=pkmn_type_colors) # Set color palette
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Attack'>

# %%
# Swarm plot with Pokemon color palette
plt.figure(figsize=(11,6)) # Set plot dimensions
sns.swarmplot(x='Type 1', y='Attack', data=df, 
              palette=pkmn_type_colors)
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Attack'>

# %% [markdown]
# ## Overlaying Plots

# %%
#First, we’ll make our figure larger using Matplotlib.
#Then, we’ll plot the violin plot. However, we’ll set inner=None to remove the bars inside the violins.
#Next, we’ll plot the swarm plot. This time, we’ll make the points black so they pop out more.
#Finally, we’ll set a title using Matplotlib.


# Set figure size with matplotlib
plt.figure(figsize=(11,6))
 
# Create plot
sns.violinplot(x='Type 1',
               y='Attack', 
               data=df, 
               inner=None, # Remove the bars inside the violins
               palette=pkmn_type_colors)
 
sns.swarmplot(x='Type 1', 
              y='Attack', 
              data=df, 
              color='k', # Make points black
              alpha=0.7) # and slightly transparent
 
# Set title with matplotlib
plt.title('Attack by Type (Overlayed Visualizations)')
# Out:
# Text(0.5, 1.0, 'Attack by Type (Overlayed Visualizations)')
