# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# worksheet 1

# 1
d = [2, 4, 6, 8, "Monday", "Tuesday"]
print(d)

# 2
d.insert(2, 100)
print(d)

# 3
for i in d:
    print(type(i), end="\t")
print()

# 4
d2 = ['Wendesday', "Thursday", "Friday" ]
print(d2)

# 5 
d = d + d2
print(d)

# 6
print(f"My favourite day of the week is {d.pop()}")

# 7
d = np.linspace(0, 35, 10)
print(d)

# 8
d = d.reshape((5, 2))
print(d)

# 9
print(d.mean().round(2))

# 10
print(d[:, 1])
# Out:
# [2, 4, 6, 8, 'Monday', 'Tuesday']
# [2, 4, 100, 6, 8, 'Monday', 'Tuesday']
# <class 'int'>	<class 'int'>	<class 'int'>	<class 'int'>	<class 'int'>	<class 'str'>	<class 'str'>
# ['Wendesday', 'Thursday', 'Friday']
# [2, 4, 100, 6, 8, 'Monday', 'Tuesday', 'Wendesday', 'Thursday', 'Friday']
# My favourite day of the week is Friday
# [ 0.          3.88888889  7.77777778 11.66666667 15.55555556 19.44444444
#  23.33333333 27.22222222 31.11111111 35.        ]
# [[ 0.          3.88888889]
#  [ 7.77777778 11.66666667]
#  [15.55555556 19.44444444]
#  [23.33333333 27.22222222]
#  [31.11111111 35.        ]]
# 17.5
# [ 3.88888889 11.66666667 19.44444444 27.22222222 35.        ]

# %%
d
# Out:
# array([[ 0.        ,  3.88888889],
#        [ 7.77777778, 11.66666667],
#        [15.55555556, 19.44444444],
#        [23.33333333, 27.22222222],
#        [31.11111111, 35.        ]])

# %%
c = np.array(d.flat)
c[0] = 5
c
# Out:
# array([ 5.        ,  3.88888889,  7.77777778, 11.66666667, 15.55555556,
#        19.44444444, 23.33333333, 27.22222222, 31.11111111, 35.        ])

# %%
d
# Out:
# array([[ 0.        ,  3.88888889],
#        [ 7.77777778, 11.66666667],
#        [15.55555556, 19.44444444],
#        [23.33333333, 27.22222222],
#        [31.11111111, 35.        ]])

# %%
c = d.reshape((10,))
c
# Out:
# array([ 0.        ,  3.88888889,  7.77777778, 11.66666667, 15.55555556,
#        19.44444444, 23.33333333, 27.22222222, 31.11111111, 35.        ])

# %%
c[0] = 5
c
# Out:
# array([ 5.        ,  3.88888889,  7.77777778, 11.66666667, 15.55555556,
#        19.44444444, 23.33333333, 27.22222222, 31.11111111, 35.        ])

# %%
d
# Out:
# array([[ 5.        ,  3.88888889],
#        [ 7.77777778, 11.66666667],
#        [15.55555556, 19.44444444],
#        [23.33333333, 27.22222222],
#        [31.11111111, 35.        ]])

# %%
# Worksheet 2

# 1
d = np.arange(-20, 26, 5)
print(d)

# 2
d2 = d*10
print(d2)

# 3
print(d2 + d)

# 4
d2 = d2.reshape(5, 2)
print(d2)

# 5
d3 = np.array([1, 2, 3, 4, 5])

# 6
# d2 * d3[: , np.newaxis]
d4 = d2 * d3.reshape(5, 1)

# 7
print(d4[[0, 2, 4], :])

# 8
print(id(d4))

# 9
d4.resize((2, 5))

# 10
d4 = d4.flatten()
print(d4)
# Out:
# [-20 -15 -10  -5   0   5  10  15  20  25]
# [-200 -150 -100  -50    0   50  100  150  200  250]
# [-220 -165 -110  -55    0   55  110  165  220  275]
# [[-200 -150]
#  [-100  -50]
#  [   0   50]
#  [ 100  150]
#  [ 200  250]]
# [[-200 -150]
#  [   0  150]
#  [1000 1250]]
# 126619728
# [-200 -150 -200 -100    0  150  400  600 1000 1250]

# %%
# worksheet 3

# 1
d = [
    ["ID", "Age", "is_part_time", "salary"],
    [1, 1, True, 1],
    [2, 2, True, 2],
    [3, 523, False, 5555],
    [4, 24, True, 5312]
]

# 2
import os
print(os.getcwd())

# 3
import csv
with open("worksheet3.csv", "w") as writer:
    c = csv.writer(writer)
    c.writerows(d)
    
# 4 
d2 = pd.read_csv("worksheet3.csv")
print(d2)

# 5
d = pd.Series([0, 1, 2, 3, 4], index=['a', 'b', 'c', 'd', 'e'])
print(d)

# 6
d2 = pd.Series([5, 6, 7, 8, 9], index=['a', 'b', 'c', 'd', 'z'])
print(d2)

d3 = d + d2
print(d3)

print(d3[d3.isna()])
d3[d3 == 5]

d4 = pd.util.testing.makeMixedDataFrame()
greater = d4[d4['A'] > 2]
print(d4)
print(greater)

d.iloc[[0, 1]]
# Out:
# D:\Programming\CLONES\uni\CSCI2000U\Exam Review
#    ID  Age  is_part_time  salary
# 0   1    1          True       1
# 1   2    2          True       2
# 2   3  523         False    5555
# 3   4   24          True    5312
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64
# a    5
# b    6
# c    7
# d    8
# z    9
# dtype: int64
# a     5.0
# b     7.0
# c     9.0
# d    11.0
# e     NaN
# z     NaN
# dtype: float64
# e   NaN
# z   NaN
# dtype: float64
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07
#      A    B     C          D
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07
# a    0
# b    1
# dtype: int64

# %%
d = pd.DataFrame({'Mon': [68, 89, np.nan], 'Wed': [71, 93, 48], 'Fri': [66, 82, 104],
'Tue': [75, 97, 43], 'Thu': [62, np.nan, 89]}, index = ["day1","day2","day3"]).T
d
# Out:
#      day1  day2   day3
# Mon  68.0  89.0    NaN
# Wed  71.0  93.0   48.0
# Fri  66.0  82.0  104.0
# Tue  75.0  97.0   43.0
# Thu  62.0   NaN   89.0

# %%
d = d.reindex(index = ['Mon', "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"], columns = ["day3", "day2", "day1"])
d
# Out:
#       day3  day2  day1
# Mon    NaN  89.0  68.0
# Tue   43.0  97.0  75.0
# Wed   48.0  93.0  71.0
# Thu   89.0   NaN  62.0
# Fri  104.0  82.0  66.0
# Sat    NaN   NaN   NaN
# Sun    NaN   NaN   NaN

# %%
d.loc[['Mon', 'Tue'], ['day3', "day2"]]
# Out:
#      day3  day2
# Mon   NaN  89.0
# Tue  43.0  97.0

# %%
d.iloc[[0, 1], [0]]
# Out:
#      day3
# Mon   NaN
# Tue  43.0

# %%
d.mean(axis=1).round(3)
# Out:
# Mon    78.500
# Tue    71.667
# Wed    70.667
# Thu    75.500
# Fri    84.000
# Sat       NaN
# Sun       NaN
# dtype: float64

# %%
# Out:
# array([1, 2, 3, 4, 5])

# %%
# 4.
d = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/ggplot2/mpg.csv")
d
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 0             1         audi      a4    1.8  1999    4    auto(l5)   f   18
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 0     29  p  compact
# ...

# %%
d.groupby(['cty']).mean(numeric_only=True).unstack()
# d.groupby(['cyl', 'drv']).size().unstack()
# Out:
#             cty
# Unnamed: 0  9      75.600000
#             11     84.300000
#             12     98.750000
#             13     88.952381
#             14     84.789474
#                      ...
# hwy         26     34.666667
#             28     35.000000
#             29     41.000000
#             33     44.000000
#             35     44.000000
# Length: 105, dtype: float64

# %%
d
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 0             1         audi      a4    1.8  1999    4    auto(l5)   f   18
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 0     29  p  compact
# ...

# %%
d.drop(0)
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# 5             6         audi      a4    2.8  1999    6  manual(m5)   f   18
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 1     29  p  compact
# ...

# %%
d.drop('manufacturer', axis=1)
# Out:
#      Unnamed: 0   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0             1      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1             2      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2             3      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3             4      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4             5      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229         230  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230         231  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231         232  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232         233  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233         234  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
d.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'Unnamed: 0'}>,
#         <AxesSubplot: title={'center': 'displ'}>],
#        [<AxesSubplot: title={'center': 'year'}>,
#         <AxesSubplot: title={'center': 'cyl'}>],
#        [<AxesSubplot: title={'center': 'cty'}>,
#         <AxesSubplot: title={'center': 'hwy'}>]], dtype=object)

# %%
a = np.arange(5)

# %%
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
a.size
# Out:
# 5
